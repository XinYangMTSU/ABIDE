# %%
# !pip install --upgrade nilearn

from nilearn.datasets import fetch_abide_pcp
# Fetch the full data and update phenotypic data and cross_validation
abide = fetch_abide_pcp(derivatives = ['rois_cc400'], pipeline = 'cpac', quality_checked = False)

y = abide.phenotypic['DX_GROUP']
# Out:
# Collecting nilearn
#   Downloading https://files.pythonhosted.org/packages/3d/9e/96f2da387ee9acaba2cbab7b596486b0231b5f6d9bf946b880536d4485fc/nilearn-0.5.0-py2.py3-none-any.whl (2.3MB)
#     100% |████████████████████████████████| 2.3MB 8.8MB/s
# Requirement already satisfied, skipping upgrade: nibabel>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from nilearn) (2.3.1)
# Installing collected packages: nilearn
# Successfully installed nilearn-0.5.0
#
# Dataset created in /root/nilearn_data/ABIDE_pcp
#
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Phenotypic_V1_0b_preprocessed1.csv ...
# Downloaded 449443 of 449443 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py:2266: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050003_rois_cc400.1D ...
# Downloaded 789127 of 789127 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050004_rois_cc400.1D ...
# Downloaded 778357 of 778357 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050005_rois_cc400.1D ...
# Downloaded 781091 of 781091 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050006_rois_cc400.1D ...
# Downloaded 779601 of 779601 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050007_rois_cc400.1D ...
# Downloaded 786242 of 786242 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050008_rois_cc400.1D ...
# Downloaded 778714 of 778714 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050009_rois_cc400.1D ...
# Downloaded 782249 of 782249 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050010_rois_cc400.1D ...
# Downloaded 774473 of 774473 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050011_rois_cc400.1D ...
# Downloaded 766000 of 766000 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050012_rois_cc400.1D ...
# Downloaded 782233 of 782233 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050013_rois_cc400.1D ...
# Downloaded 783968 of 783968 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050014_rois_cc400.1D ...
# Downloaded 778642 of 778642 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050015_rois_cc400.1D ...
# Downloaded 778976 of 778976 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050016_rois_cc400.1D ...
# Downloaded 777279 of 777279 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050017_rois_cc400.1D ...
# Downloaded 782788 of 782788 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050019_rois_cc400.1D ...
# Downloaded 779495 of 779495 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050020_rois_cc400.1D ...
# Downloaded 780778 of 780778 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050022_rois_cc400.1D ...
# Downloaded 780109 of 780109 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050023_rois_cc400.1D ...
# Downloaded 783266 of 783266 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050024_rois_cc400.1D ...
# Downloaded 772561 of 772561 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050025_rois_cc400.1D ...
# Downloaded 778198 of 778198 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050026_rois_cc400.1D ...
# Downloaded 785678 of 785678 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050027_rois_cc400.1D ...
# Downloaded 778797 of 778797 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/Pitt_0050028_rois_cc400.1D ...
# Downloaded 786180 of 786180 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/
seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051579_rois_cc400.1D ...
# Downloaded 781329 of 781329 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051580_rois_cc400.1D ...
# Downloaded 781284 of 781284 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051581_rois_cc400.1D ...
# Downloaded 777400 of 777400 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051582_rois_cc400.1D ...
# Downloaded 778717 of 778717 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051583_rois_cc400.1D ...
# Downloaded 780874 of 780874 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051584_rois_cc400.1D ...
# Downloaded 783016 of 783016 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/SBL_0051585_rois_cc400.1D ...
# Downloaded 784370 of 784370 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/MaxMun_a_0051606_rois_cc400.1D ...
# Downloaded 456524 of 456524 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc400/MaxMun_a_0051607_rois_cc400.1D ...
# Downloaded 460684 of 460684 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)

# %% [markdown]
# =====================================
# Logistic Regression:
# =====================================

# %%
measure = 'correlation'
C = [1,10,100]
lr_params = {'C': C}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
lr = LogisticRegression()

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(lr, lr_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_


print("best_estimators:",best_estimators)
print("best_scores:",best_scores)


'''
best_estimators: LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l2', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)
best_scores: 0.7178743961352657
'''
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  7.5min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# best_estimators: LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# best_scores: 0.7178743961352657
# "\nbest_estimators: LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,\n          intercept_scaling=1, max_iter=100, multi_class='warn',\n          n_jobs=None, penalty='l2', random_state=None, solver='warn',\n          tol=0.0001, verbose=0, warm_start=False)\nbest_scores: 0.7178743961352657\n"

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = LogisticRegression(C = 10)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)
   
print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)  

'''
cross_recall: 0.7069306930693069
cross_precision: 0.7128601345924069
'''
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.2min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# cross_recall: 0.7069306930693069
# cross_precision: 0.7128601345924069
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.2min finished
# '\ncross_recall: 0.7069306930693069\ncross_precision: 0.7128601345924069\n'

# %% [markdown]
# ==============================================
# Ridge
# ==============================================

# %%
measure = 'correlation'
alpha = [10,100,1000]
rc_params = {'alpha': alpha}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import RidgeClassifier


skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
rc = RidgeClassifier()

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(rc, rc_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_


print("best_estimators:",best_estimators)
print("best_scores:",best_scores)

'''
best_estimators: RidgeClassifier(alpha=100, class_weight=None, copy_X=True, fit_intercept=True,
        max_iter=None, normalize=False, random_state=None, solver='auto',
        tol=0.001)
best_scores: 0.7198067632850241
'''
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  1.4min finished
# best_estimators: RidgeClassifier(alpha=100, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='auto',
#         tol=0.001)
# best_scores: 0.7198067632850241
# "\nbest_estimators: RidgeClassifier(alpha=100, class_weight=None, copy_X=True, fit_intercept=True,\n        max_iter=None, normalize=False, random_state=None, solver='auto',\n        tol=0.001)\nbest_scores: 0.7198067632850241\n"

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = RidgeClassifier(alpha=100)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)
  
print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)

'''
cross_recall: 0.7089108910891089
cross_precision: 0.7152768302037839
'''
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   26.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# cross_recall: 0.7089108910891089
# cross_precision: 0.7152768302037839
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   26.2s finished
# '\ncross_recall: 0.7089108910891089\ncross_precision: 0.7152768302037839\n'

# %% [markdown]
# ===========================================
# linearSVC l2
# ===========================================

# %%
measure = 'correlation'
C = [0.0001, 0.001, 0.01]
svc_params = {'C': C}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import LinearSVC

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
svc_l2 = LinearSVC()

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(svc_l2, svc_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_

print("best_estimators:",best_estimators)
print("best_scores:",best_scores)


'''
best_estimators: LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
     intercept_scaling=1, loss='squared_hinge', max_iter=1000,
     multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
     verbose=0)
best_scores: 0.7140096618357488
'''
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed: 14.4min finished
# best_estimators: LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)
# best_scores: 0.7140096618357488
# "\nbest_estimators: LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,\n     intercept_scaling=1, loss='squared_hinge', max_iter=1000,\n     multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,\n     verbose=0)\nbest_scores: 0.7140096618357488\n"

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = LinearSVC(C=0.001)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)

print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)

'''
cross_recall: 0.700990099009901
cross_precision: 0.7093445526760773
'''
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  6.7min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# cross_recall: 0.700990099009901
# cross_precision: 0.7093445526760773
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  6.7min finished
# '\ncross_recall: 0.700990099009901\ncross_precision: 0.7093445526760773\n'

# %% [markdown]
# =====================================
# svm rbf
# =====================================

# %%
measure = 'correlation'
C = [100,1000,10000]
svc_params = {'C': C}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import SVC

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
svc_rbf = SVC(gamma='auto')

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc400)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(svc_rbf, svc_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_

print("best_estimators:",best_estimators)
print("best_scores:",best_scores)

'''
best_estimators: SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
  decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
  max_iter=-1, probability=False, random_state=None, shrinking=True,
  tol=0.001, verbose=False)
best_scores: 0.7140096618357488
'''
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed: 30.1min finished
# best_estimators: SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# best_scores: 0.7140096618357488
# "\nbest_estimators: SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,\n  decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',\n  max_iter=-1, probability=False, random_state=None, shrinking=True,\n  tol=0.001, verbose=False)\nbest_scores: 0.7140096618357488\n"

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = SVC(gamma='auto',C=1000)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall', cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision', cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)

print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)

'''
cross_recall: 0.699009900990099
cross_precision: 0.711200621273261
'''
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  9.9min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# cross_recall: 0.699009900990099
# cross_precision: 0.711200621273261
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  9.8min finished
# '\ncross_recall: 0.699009900990099\ncross_precision: 0.711200621273261\n'
