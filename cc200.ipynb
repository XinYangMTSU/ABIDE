# %%
# !pip install --upgrade nilearn

from nilearn.datasets import fetch_abide_pcp
# Fetch the full data and update phenotypic data and cross_validation
abide = fetch_abide_pcp(derivatives = ['rois_cc200'], pipeline = 'cpac', quality_checked = False)

y = abide.phenotypic['DX_GROUP']
# Out:
# Requirement already up-to-date: nilearn in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied, skipping upgrade: nibabel>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from nilearn) (2.3.1)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py:2266: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050003_rois_cc200.1D ...
# Downloaded 401453 of 401453 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050004_rois_cc200.1D ...
# Downloaded 395590 of 395590 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050005_rois_cc200.1D ...
# Downloaded 397353 of 397353 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050006_rois_cc200.1D ...
# Downloaded 396180 of 396180 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050007_rois_cc200.1D ...
# Downloaded 400860 of 400860 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050008_rois_cc200.1D ...
# Downloaded 397021 of 397021 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050009_rois_cc200.1D ...
# Downloaded 397427 of 397427 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050010_rois_cc200.1D ...
# Downloaded 392959 of 392959 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050011_rois_cc200.1D ...
# Downloaded 393408 of 393408 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050012_rois_cc200.1D ...
# Downloaded 397670 of 397670 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050013_rois_cc200.1D ...
# Downloaded 399117 of 399117 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050014_rois_cc200.1D ...
# Downloaded 395891 of 395891 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050015_rois_cc200.1D ...
# Downloaded 395942 of 395942 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050016_rois_cc200.1D ...
# Downloaded 395851 of 395851 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050017_rois_cc200.1D ...
# Downloaded 400776 of 400776 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050019_rois_cc200.1D ...
# Downloaded 397013 of 397013 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050020_rois_cc200.1D ...
# Downloaded 396717 of 396717 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050022_rois_cc200.1D ...
# Downloaded 396833 of 396833 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050023_rois_cc200.1D ...
# Downloaded 398628 of 398628 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050024_rois_cc200.1D ...
# Downloaded 392947 of 392947 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050025_rois_cc200.1D ...
# Downloaded 395951 of 395951 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050026_rois_cc200.1D ...
# Downloaded 400585 of 400585 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050027_rois_cc200.1D ...
# Downloaded 396170 of 396170 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050028_rois_cc200.1D ...
# Downloaded 400009 of 400009 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050029_rois_cc200.1D ...
# Downloaded 396613 of 396613 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050030_rois_cc200.1D ...
# Downloaded 395095 of 395095 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050031_rois_cc200.1D ...
# Downloaded 399097 of 399097 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050032_rois_cc200.1D ...
# Downloaded 395429 of 395429 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050033_rois_cc200.1D ...
# Downloaded 399076 of 399076 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050034_rois_cc200.1D ...
# Downloaded 397616 of 397616 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050035_rois_cc200.1D ...
# Downloaded 400470 of 400470 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050036_rois_cc200.1D ...
# Downloaded 395613 of 395613 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050037_rois_cc200.1D ...
# Downloaded 395991 of 395991 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050038_rois_cc200.1D ...
# Downloaded 396448 of 396448 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050039_rois_cc200.1D ...
# Downloaded 406450 of 406450 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050040_rois_cc200.1D ...
# Downloaded 395655 of 395655 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050041_rois_cc200.1D ...
# Downloaded 393634 of 393634 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050042_rois_cc200.1D ...
# Downloaded 398037 of 398037 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0050043_rois_cc200.1D ...
# Downloaded 395528 of 395528 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Pitt_0
bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051463_rois_cc200.1D ...
# Downloaded 293222 of 293222 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051464_rois_cc200.1D ...
# Downloaded 279382 of 279382 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051465_rois_cc200.1D ...
# Downloaded 294134 of 294134 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051466_rois_cc200.1D ...
# Downloaded 283731 of 283731 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051467_rois_cc200.1D ...
# Downloaded 290817 of 290817 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051468_rois_cc200.1D ...
# Downloaded 288602 of 288602 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051469_rois_cc200.1D ...
# Downloaded 219456 of 219456 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051470_rois_cc200.1D ...
# Downloaded 290254 of 290254 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051471_rois_cc200.1D ...
# Downloaded 275073 of 275073 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051472_rois_cc200.1D ...
# Downloaded 293714 of 293714 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051473_rois_cc200.1D ...
# Downloaded 290479 of 290479 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051474_rois_cc200.1D ...
# Downloaded 293593 of 293593 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051476_rois_cc200.1D ...
# Downloaded 293111 of 293111 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051477_rois_cc200.1D ...
# Downloaded 294976 of 294976 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051478_rois_cc200.1D ...
# Downloaded 186907 of 186907 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051479_rois_cc200.1D ...
# Downloaded 293724 of 293724 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051480_rois_cc200.1D ...
# Downloaded 290842 of 290842 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051481_rois_cc200.1D ...
# Downloaded 294379 of 294379 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051482_rois_cc200.1D ...
# Downloaded 293100 of 293100 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051483_rois_cc200.1D ...
# Downloaded 288414 of 288414 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051484_rois_cc200.1D ...
# Downloaded 293070 of 293070 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051485_rois_cc200.1D ...
# Downloaded 293425 of 293425 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051486_rois_cc200.1D ...
# Downloaded 292991 of 292991 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051487_rois_cc200.1D ...
# Downloaded 293398 of 293398 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051488_rois_cc200.1D ...
# Downloaded 294992 of 294992 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051489_rois_cc200.1D ...
# Downloaded 294482 of 294482 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051490_rois_cc200.1D ...
# Downloaded 289840 of 289840 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051491_rois_cc200.1D ...
# Downloaded 292076 of 292076 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051492_rois_cc200.1D ...
# Downloaded 293481 of 293481 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/Caltech_0051493_rois_cc200.1D ...
# Downloaded 290864 of 290864 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051556_rois_cc200.1D ...
# Downloaded 404641 of 404641 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051557_rois_cc200.1D ...
# Downloaded 397711 of 397711 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051558_rois_cc200.1D ...
# Downloaded 384177 of 384177 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051559_rois_cc200.1D ...
# Downloaded 400677 of 400677 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051560_rois_cc200.1D ...
# Downloaded 396578 of 396578 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051561_rois_cc200.1D ...
# Downloaded 398691 of 398691 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051562_rois_cc200.1D ...
# Downloaded 397255 of 397255 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051563_rois_cc200.1D ...
# Downloaded 398570 of 398570 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051564_rois_cc200.1D ...
# Downloaded 397963 of 397963 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051565_rois_cc200.1D ...
# Downloaded 396255 of 396255 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051566_rois_cc200.1D ...
# Downloaded 395118 of 395118 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051567_rois_cc200.1D ...
# Downloaded 396971 of 396971 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051568_rois_cc200.1D ...
# Downloaded 399670 of 399670 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051569_rois_cc200.1D ...
# Downloaded 396383 of 396383 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051570_rois_cc200.1D ...
# Downloaded 397939 of 397939 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051571_rois_cc200.1D ...
# Downloaded 397362 of 397362 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051572_rois_cc200.1D ...
# Downloaded 396753 of 396753 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051573_rois_cc200.1D ...
# Downloaded 395818 of 395818 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051574_rois_cc200.1D ...
# Downloaded 395320 of 395320 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051575_rois_cc200.1D ...
# Downloaded 391105 of 391105 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051576_rois_cc200.1D ...
# Downloaded 396634 of 396634 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051577_rois_cc200.1D ...
# Downloaded 396128 of 396128 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051578_rois_cc200.1D ...
# Downloaded 395004 of 395004 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051579_rois_cc200.1D ...
# Downloaded 398629 of 398629 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051580_rois_cc200.1D ...
# Downloaded 398631 of 398631 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051581_rois_cc200.1D ...
# Downloaded 395128 of 395128 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051582_rois_cc200.1D ...
# Downloaded 396558 of 396558 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051583_rois_cc200.1D ...
# Downloaded 398233 of 398233 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051584_rois_cc200.1D ...
# Downloaded 401044 of 401044 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/SBL_0051585_rois_cc200.1D ...
# Downloaded 399103 of 399103 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/MaxMun_a_0051606_rois_cc200.1D ...
# Downloaded 231718 of 231718 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)
# Downloading data from https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/rois_cc200/MaxMun_a_0051607_rois_cc200.1D ...
# Downloaded 234196 of 234196 bytes (100.0%,    0.0s remaining) ...done. (0 seconds, 0 min)

# %% [markdown]
# =====================================
# Logistic Regression:
# =====================================

# %%
measure = 'correlation'
C = [0.001, 0.01, 0.1]
lr_params = {'C': C}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
lr = LogisticRegression()

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc200)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(lr, lr_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_


print("best_estimators:",best_estimators)
print("best_scores:",best_scores)

'''
best_estimators: [LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l2', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)]
best_scores: [0.6908212560386473]
'''

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = LogisticRegression(C = 0.01)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)
   
print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)  

'''
cross_recall: [0.6673267326732674]
cross_precision: [0.6904341921519341]
'''

# %% [markdown]
# ==============================================
# Ridge
# ==============================================

# %%
measure = 'correlation'
alpha = [100,1000,10000]
rc_params = {'alpha': alpha}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.linear_model import RidgeClassifier


skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
rc = RidgeClassifier()

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc200)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(rc, rc_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_


print("best_estimators:",best_estimators)
print("best_scores:",best_scores)

'''
best_estimators: [RidgeClassifier(alpha=1000, class_weight=None, copy_X=True,
        fit_intercept=True, max_iter=None, normalize=False,
        random_state=None, solver='auto', tol=0.001)]
best_scores: [0.6927536231884058]
'''

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = RidgeClassifier(alpha=1000)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)
  
print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)

'''
cross_recall: [0.6594059405940593]
cross_precision: [0.6960889851629156]
'''

# %% [markdown]
# ===========================================
# linearSVC l2
# ===========================================

# %%
measure = 'correlation'
C = [0.0001, 0.001, 0.01]
svc_params = {'C': C}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import LinearSVC

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
svc_l2 = LinearSVC()

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc200)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(svc_l2, svc_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_

print("best_estimators:",best_estimators)
print("best_scores:",best_scores)

'''
best_estimators: [LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
     intercept_scaling=1, loss='squared_hinge', max_iter=1000,
     multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
     verbose=0)]
best_scores: [0.6859903381642513]
'''
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  3.3min finished
# best_estimators: LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)
# best_scores: 0.6859903381642513
# "\nbest_estimators: [LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,\n     intercept_scaling=1, loss='squared_hinge', max_iter=1000,\n     multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,\n     verbose=0)]\nbest_scores: [0.6859903381642513]\n"

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = LinearSVC(C = 0.001)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)

print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)

'''
cross_recall: [0.6613861386138613]
cross_precision: [0.6856377307555428]
'''
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.0min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# cross_recall: 0.6613861386138613
# cross_precision: 0.6856377307555428
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.0min finished
# '\ncross_recall: [0.6613861386138613]\ncross_precision: [0.6856377307555428]\n'

# %% [markdown]
# =====================================
# svm rbf
# =====================================

# %%
measure = 'correlation'
C = [1,10,100]
svc_params = {'C': C}

from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.svm import SVC

skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 10)
svc_rbf = SVC(gamma='auto')

y[y==2] = 0

from nilearn.connectome import ConnectivityMeasure
from nilearn.connectome import sym_matrix_to_vec

conn_est = ConnectivityMeasure(kind = measure)
conn_matrices = conn_est.fit_transform(abide.rois_cc200)
X = sym_matrix_to_vec(conn_matrices)

gcv = GridSearchCV(svc_rbf, svc_params, n_jobs = -1, cv = skf, verbose = 1)
gcv.fit(X, y)
best_estimators = gcv.best_estimator_
best_scores = gcv.best_score_

print("best_estimators:",best_estimators)
print("best_scores:",best_scores)

'''
best_estimators: SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
  decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
  max_iter=-1, probability=False, random_state=None, shrinking=True,
  tol=0.001, verbose=False)
best_scores: 0.6811594202898551
'''
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  7.3min finished
# best_estimators: SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# best_scores: 0.6811594202898551
# "\nbest_estimators: SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,\n  decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',\n  max_iter=-1, probability=False, random_state=None, shrinking=True,\n  tol=0.001, verbose=False)\nbest_scores: 0.6811594202898551\n"

# %%
from sklearn.model_selection import cross_val_score
import numpy as np
#best parameter for each measure
lr = SVC(gamma='auto',C=10)

#recall == sensitivity
recall = cross_val_score(lr, X, y, scoring = 'recall',cv = skf, verbose = 1)
precision = cross_val_score(lr, X, y, scoring = 'precision',cv = skf, verbose = 1)
    
cross_recall = np.mean(recall)
cross_precision = np.mean(precision)

print("cross_recall:",cross_recall)
print("cross_precision:",cross_precision)

'''
cross_recall: 0.6257425742574256
cross_precision: 0.693116442730704
'''
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.4min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# cross_recall: 0.6257425742574256
# cross_precision: 0.693116442730704
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.4min finished
# '\ncross_recall: [0.6613861386138613]\ncross_precision: [0.6856377307555428]\n'
